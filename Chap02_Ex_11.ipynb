# %% [markdown]
# <a href="https://colab.research.google.com/github/Tatsuyuki-Matsuda/EU_M_Math-Repository/blob/main/Chap02_Ex_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercise 2-11
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
plt.figure(figsize =(10, 6))
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.grid(True)
